# %%
import sys
import os
root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)

from utils.color_utils import ColorLibrary

# Reload the color library from the categorized CSV file
cl_reloaded = ColorLibrary.from_categorized_csv('../datasets/categorized_colors.csv')
cl_reloaded.summary()
cl_reloaded.plot_category_hue_lightness('red')
# Out:
# red: 20 colors
# orange: 19 colors
# yellow: 34 colors
# green: 44 colors
# blue: 31 colors
# violet: 11 colors
# purple: 25 colors
# white: 6 colors
# gray: 20 colors
# black: 7 colors
# pink: 25 colors
# brown: 27 colors
# olive: 17 colors
